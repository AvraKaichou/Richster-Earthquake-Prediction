# %%
import streamlit as st
import joblib
import numpy as np

# Load model dan preprocessing
model = joblib.load('catboost_model.pkl')
scaler = joblib.load('scaler.pkl')
pca = joblib.load('pca.pkl')
feature_names = joblib.load('feature_names.pkl')

st.set_page_config(page_title="Prediksi Kerusakan Bangunan", layout="centered")
st.title("🏚️ Prediksi Tingkat Kerusakan Bangunan akibat Gempa")

# ==== Input dari user ====
geo_level_1_id = st.number_input("Geo Level 1 ID", min_value=0, max_value=50, value=15)
geo_level_2_id = st.number_input("Geo Level 2 ID", min_value=0, max_value=100, value=25)
geo_level_3_id = st.number_input("Geo Level 3 ID", min_value=0, max_value=200, value=50)

count_floors_pre_eq = st.number_input("Jumlah Lantai Sebelum Gempa", min_value=1, value=2)
age = st.number_input("Umur Bangunan (tahun)", min_value=0, value=20)
area_percentage = st.slider("Persentase Area (%)", 0, 100, 10)
height_percentage = st.slider("Persentase Tinggi (%)", 0, 100, 5)

# ==== Fitur kategorikal ====
land_surface = st.selectbox("Kondisi Permukaan Tanah", ["Flat", "Moderate", "Steep"])
foundation = st.selectbox("Tipe Pondasi", ["RC", "Stone", "Mud", "Brick", "Other"])
roof = st.selectbox("Tipe Atap", ["Bamboo", "Metal", "Thatched", "Other"])
ground_floor = st.selectbox("Tipe Lantai Dasar", ["Mud", "Cement", "Wood", "Brick"])
other_floor = st.selectbox("Tipe Lantai Atas", ["None", "Timber", "RC", "Other"])
position = st.selectbox("Posisi Bangunan", ["Attached", "Corner", "Independent"])
plan_config = st.selectbox("Konfigurasi Rencana", ["Rectangular", "Square", "L-shape", "T-shape", "Other"])

count_families = st.number_input("Jumlah Keluarga di Bangunan", min_value=1, value=1)

# ==== Mapping kategori ke angka ====
land_surface_dict = {"Flat": 0, "Moderate": 1, "Steep": 2}
foundation_dict = {"RC": 0, "Stone": 1, "Mud": 2, "Brick": 3, "Other": 4}
roof_dict = {"Bamboo": 0, "Metal": 1, "Thatched": 2, "Other": 3}
ground_floor_dict = {"Mud": 0, "Cement": 1, "Wood": 2, "Brick": 3}
other_floor_dict = {"None": 0, "Timber": 1, "RC": 2, "Other": 3}
position_dict = {"Attached": 0, "Corner": 1, "Independent": 2}
plan_dict = {"Rectangular": 0, "Square": 1, "L-shape": 2, "T-shape": 3, "Other": 4}

# ==== Data gabungan ====
data = np.array([[ 
    geo_level_1_id,
    geo_level_2_id,
    geo_level_3_id,
    age,
    area_percentage,
    height_percentage,
    land_surface_dict[land_surface],
    foundation_dict[foundation],
    roof_dict[roof],
    ground_floor_dict[ground_floor],
    other_floor_dict[other_floor],
    position_dict[position],
    plan_dict[plan_config]
]])


# ==== Prediksi ====
if st.button("🔍 Prediksi"):
    data_scaled = scaler.transform(data)
    data_pca = pca.transform(data_scaled)
    pred = model.predict(data_pca)[0]
    label = ["Low", "Medium", "High"][int(pred)]
    st.success(f"🏷️ Hasil Prediksi Tingkat Kerusakan: **{label}**")
# Out:
# 2025-05-26 11:45:33.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-26 11:45:33.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
